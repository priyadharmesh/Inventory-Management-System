# %%
import json

# %%
fd = open("record.json",'r')
r = fd.read()
fd.close()

# %%
r
# Out:
# '{"1001": {"name": "Choco Cake", "qn": 34, "pr": 100}, "1002": {"name": "Milk Cake", "pr": 800, "qn": 100}, "1003": {"name": "Drink", "pr": 85, "qn": 100}, "1004": {"name": "Candy", "pr": 5, "qn": 1000}, "1005": {"name": "Pen", "pr": 20, "qn": 100}, "1006": {"name": "Phone", "pr": 50000, "qn": 10}, "1007": {"name": "Mic", "pr": 1500, "qn": 0}, "1008": {"name": "Case", "pr": 599, "qn": 5}, "1009": {"name": "Keyboard", "pr": 1999, "qn": 10}}'

# %%
len(r)
# Out:
# 1468

# %%
record= json.loads(r)

# %%
record
# Out:
# {'1001': {'name': 'Choco Cake', 'pr': 100, 'qn': 50},
#  '1002': {'name': 'Milk Cake', 'pr': 800, 'qn': 120},
#  '1003': {'name': 'Drink', 'pr': 85, 'qn': 130},
#  '1004': {'name': 'Candy', 'pr': 5, 'qn': 2000},
#  '1005': {'name': 'Pen', 'pr': 20, 'qn': 200},
#  '1006': {'name': 'Phone', 'pr': 50000, 'qn': 10},
#  '1007': {'name': 'Mic', 'pr': 1500, 'qn': 0},
#  '1008': {'name': 'Case', 'pr': 599, 'qn': 5},
#  '1009': {'name': 'Keyboard', 'pr': 1999, 'qn': 10},
#  '1010': {'name': 'maggie', 'pr': 20, 'qn': 30},
#  '1011': {'name': 'bread', 'pr': 40, 'qn': 50},
#  '1012': {'name': 'piano', 'pr': 300, 'qn': 30},
#  '1013': {'name': 'tabla', 'pr': 350, 'qn': 20},
#  '1014': {'name': 'biscuits', 'pr': 15, 'qn': 140},
#  '1015': {'name': 'soaps', 'pr': 10, 'qn': 80},
#  '1016': {'name': 'chairs', 'pr': 120, 'qn': 140},
#  '1017': {'name': 'toys', 'pr': 50, 'qn': 30},
#  '1018': {'name': 'pillows', 'pr': 90, 'qn': 20},
#  '1019': {'name': 'bedsheets', 'pr': 150, 'qn': 30},
# ...

# %%
record.keys()
# Out:
# dict_keys(['1001', '1002', '1003', '1004', '1005', '1006', '1007', '1008', '1009', '1012', '1013', '1014', '1010', '1011', '1015', '1016', '1017', '1019', '1018', '1020', '1021', '1022', '1023', '1024', '1025', '1026', '1027', '1028', '1029', '1030'])

# %%
record['1003']['qn']
# Out:
# 130

# %% [markdown]
# **Adding New Item to Inventory**

# %%
prod_id = str(input("Enter product id:"))
name = str(input("Enter name:"))
pr = int(input("Enter price:"))
qnn = int(input("Enter quantity:"))
 
for i in record.keys():
  if i==prod_id:
    q=record[prod_id]['qn'];
    print(q)
    record[i]['qn']= q+qnn;
    print(record[i]['qn'])
    qnn=record[i]['qn']

record[prod_id] = {'name': name, 'pr': pr, 'qn': qnn}   




record
# Out:
# Enter product id:1004
# Enter name:Candy
# Enter price:5
# Enter quantity:100
# 2000
# 2100
# {'1001': {'name': 'Choco Cake', 'pr': 100, 'qn': 50},
#  '1002': {'name': 'Milk Cake', 'pr': 800, 'qn': 120},
#  '1003': {'name': 'Drink', 'pr': 85, 'qn': 130},
#  '1004': {'name': 'Candy', 'pr': 5, 'qn': 2100},
#  '1005': {'name': 'Pen', 'pr': 20, 'qn': 200},
#  '1006': {'name': 'Phone', 'pr': 50000, 'qn': 10},
#  '1007': {'name': 'Mic', 'pr': 1500, 'qn': 0},
#  '1008': {'name': 'Case', 'pr': 599, 'qn': 5},
#  '1009': {'name': 'Keyboard', 'pr': 1999, 'qn': 10},
#  '1010': {'name': 'maggie', 'pr': 20, 'qn': 30},
#  '1011': {'name': 'bread', 'pr': 40, 'qn': 50},
#  '1012': {'name': 'piano', 'pr': 300, 'qn': 30},
#  '1013': {'name': 'tabla', 'pr': 350, 'qn': 20},
#  '1014': {'name': 'biscuits', 'pr': 15, 'qn': 140},
#  '1015': {'name': 'soaps', 'pr': 10, 'qn': 80},
#  '1016': {'name': 'chairs', 'pr': 120, 'qn': 140},
#  '1017': {'name': 'toys', 'pr': 50, 'qn': 30},
# ...

# %%
js = json.dumps(record)

fd = open("record.json",'w')
fd.write(js)
fd.close()

# %% [markdown]
# **Purchasing products**

# %%
fd = open("record.json",'r')
r = fd.read()
fd.close()

records = json.loads(r)

# %%
records
# Out:
# {'1001': {'name': 'Choco Cake', 'pr': 100, 'qn': 50},
#  '1002': {'name': 'Milk Cake', 'pr': 800, 'qn': 120},
#  '1003': {'name': 'Drink', 'pr': 85, 'qn': 130},
#  '1004': {'name': 'Candy', 'pr': 5, 'qn': 2100},
#  '1005': {'name': 'Pen', 'pr': 20, 'qn': 200},
#  '1006': {'name': 'Phone', 'pr': 50000, 'qn': 10},
#  '1007': {'name': 'Mic', 'pr': 1500, 'qn': 0},
#  '1008': {'name': 'Case', 'pr': 599, 'qn': 5},
#  '1009': {'name': 'Keyboard', 'pr': 1999, 'qn': 10},
#  '1010': {'name': 'maggie', 'pr': 20, 'qn': 30},
#  '1011': {'name': 'bread', 'pr': 40, 'qn': 50},
#  '1012': {'name': 'piano', 'pr': 300, 'qn': 30},
#  '1013': {'name': 'tabla', 'pr': 350, 'qn': 20},
#  '1014': {'name': 'biscuits', 'pr': 15, 'qn': 140},
#  '1015': {'name': 'soaps', 'pr': 10, 'qn': 80},
#  '1016': {'name': 'chairs', 'pr': 120, 'qn': 140},
#  '1017': {'name': 'toys', 'pr': 50, 'qn': 30},
#  '1018': {'name': 'pillows', 'pr': 90, 'qn': 20},
#  '1019': {'name': 'bedsheets', 'pr': 150, 'qn': 30},
# ...

# %% [markdown]
# **Purchase**

# %%
ui_prod  = str(input("Enter the product_Id: "))
ui_quant = int(input("Enter the quantity: "))

if qnn>=ui_quant:
  print("Product: ", records[ui_prod]['name'])
  print("Price: ", records[ui_prod]['pr'])
  print("Billing Amount: ", records[ui_prod]['pr'] * ui_quant)
  records[ui_prod]['qn'] = records[ui_prod]['qn'] - ui_quant

else:
  print("Product not available,Sorry")
# Out:
# Enter the product_Id: 1019
# Enter the quantity: 5
# Product:  bedsheets
# Price:  150
# Billing Amount:  750

# %%
records
# Out:
# {'1001': {'name': 'Choco Cake', 'pr': 100, 'qn': 50},
#  '1002': {'name': 'Milk Cake', 'pr': 800, 'qn': 120},
#  '1003': {'name': 'Drink', 'pr': 85, 'qn': 130},
#  '1004': {'name': 'Candy', 'pr': 5, 'qn': 1950},
#  '1005': {'name': 'Pen', 'pr': 20, 'qn': 190},
#  '1006': {'name': 'Phone', 'pr': 50000, 'qn': 10},
#  '1007': {'name': 'Mic', 'pr': 1500, 'qn': 0},
#  '1008': {'name': 'Case', 'pr': 599, 'qn': 5},
#  '1009': {'name': 'Keyboard', 'pr': 1999, 'qn': 10},
#  '1010': {'name': 'maggie', 'pr': 20, 'qn': 26},
#  '1011': {'name': 'bread', 'pr': 40, 'qn': 40},
#  '1012': {'name': 'piano', 'pr': 300, 'qn': 20},
#  '1013': {'name': 'tabla', 'pr': 350, 'qn': 20},
#  '1014': {'name': 'biscuits', 'pr': 15, 'qn': 120},
#  '1015': {'name': 'soaps', 'pr': 10, 'qn': 77},
#  '1016': {'name': 'chairs', 'pr': 120, 'qn': 140},
#  '1017': {'name': 'toys', 'pr': 50, 'qn': 28},
#  '1018': {'name': 'pillows', 'pr': 90, 'qn': 20},
#  '1019': {'name': 'bedsheets', 'pr': 150, 'qn': 25},
# ...

# %% [markdown]
# **Update inventory after purchase**

# %%
js = json.dumps(records)

fd = open("record.json",'w')
fd.write(js)
fd.close()

# %%
records
# Out:
# {'1001': {'name': 'Choco Cake', 'pr': 100, 'qn': 50},
#  '1002': {'name': 'Milk Cake', 'pr': 800, 'qn': 120},
#  '1003': {'name': 'Drink', 'pr': 85, 'qn': 130},
#  '1004': {'name': 'Candy', 'pr': 5, 'qn': 1950},
#  '1005': {'name': 'Pen', 'pr': 20, 'qn': 190},
#  '1006': {'name': 'Phone', 'pr': 50000, 'qn': 10},
#  '1007': {'name': 'Mic', 'pr': 1500, 'qn': 0},
#  '1008': {'name': 'Case', 'pr': 599, 'qn': 5},
#  '1009': {'name': 'Keyboard', 'pr': 1999, 'qn': 10},
#  '1010': {'name': 'maggie', 'pr': 20, 'qn': 26},
#  '1011': {'name': 'bread', 'pr': 40, 'qn': 40},
#  '1012': {'name': 'piano', 'pr': 300, 'qn': 20},
#  '1013': {'name': 'tabla', 'pr': 350, 'qn': 20},
#  '1014': {'name': 'biscuits', 'pr': 15, 'qn': 120},
#  '1015': {'name': 'soaps', 'pr': 10, 'qn': 77},
#  '1016': {'name': 'chairs', 'pr': 120, 'qn': 140},
#  '1017': {'name': 'toys', 'pr': 50, 'qn': 28},
#  '1018': {'name': 'pillows', 'pr': 90, 'qn': 20},
#  '1019': {'name': 'bedsheets', 'pr': 150, 'qn': 25},
# ...

# %% [markdown]
# ***Sales.json***

# %%
# sales = {1 : {'prod' : ui_prod, 'qn' : ui_quant, 'amount': records[ui_prod]['pr'] * ui_quant}}

# %%
# sales
# Out:
# {1: {'amount': 80, 'prod': '1010', 'qn': 4}}

# %%
{(len(sales) + 1):{'prod' : ui_prod, 'qn' : ui_quant, 'amount': records[ui_prod]['pr'] * ui_quant}}
# Out:
# {10: {'amount': 750, 'prod': '1019', 'qn': 5}}

# %%
sales[(len(sales) + 1)]={'prod' : ui_prod, 'qn' : ui_quant, 'amount': records[ui_prod]['pr'] * ui_quant}

# %%
sales
# Out:
# {1: {'amount': 80, 'prod': '1010', 'qn': 4},
#  2: {'amount': 80, 'prod': '1010', 'qn': 4},
#  3: {'amount': 80, 'prod': '1010', 'qn': 4},
#  4: {'amount': 400, 'prod': '1011', 'qn': 10},
#  5: {'amount': 150, 'prod': '1029', 'qn': 5},
#  6: {'amount': 3000, 'prod': '1012', 'qn': 10},
#  7: {'amount': 300, 'prod': '1014', 'qn': 20},
#  8: {'amount': 30, 'prod': '1015', 'qn': 3},
#  9: {'amount': 100, 'prod': '1017', 'qn': 2},
#  10: {'amount': 750, 'prod': '1019', 'qn': 5}}

# %%
sale = json.dumps(sales)

# %% [markdown]
# **to update in sales.json**

# %%
js=json.dumps(sales)
fd=open("sales.json",'w') 
fd.write(js) 
fd.close()
